# %%
#Write a Python program to print "Hello, World!
print("Hello,World")

#Write a Python program that displays your name and age8
name=input("Enter your name:")
age=int(input("Enter you age"))
print("Name, name")
print("Age, age")

#Write code to print all the pre-defined keywords in Python using the keyword library.
import keyword
print (keyword.kwlist)

#Write a program that checks if a given word is a Python keyword.
import keyword
word=input("Enter a word:")
if keyword.iskeyword(word):
 print(word,"is a keyword")
else:
  print(word,"is not a keyword")

# Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
#for each.
my_list = [10,20,30]
my_tuple = [10,20,30]
print("Original list:",my_list )
my_list[1]=99
print("Modified list:", my_list)
print("Original tuple:", my_tuple)
my_tuple[1]=99
print("Modified tuple:")

#Write a function to demonstrate the behavior of mutable and immutable arguments.
def modify_list(my_list):
  my_list.append(4)
  print("Inside the funtion:,my_list")
  my_list=[20,30,40]
  print("Outside the function:my_list")
  modify_list(my_list)
  print("Final list:my_list")

#Write a program that performs basic arithmetic operations on two user-input numbers.
num1=float(input("Enter the first number"))
num2=float(input("Enter the second number"))
print("Addition: num1+num2")
print("Subtraction: num1-num2")
print("Multiplication: num1*num2")
print ("Division: num1%num2")

# Write a program to demonstrate the use of logical operators.
a=True
b=False
print("Logical AND:, a and b")
print("Logical OR:, a or b")
print("Logical NOT:, not A")

#Write a Python program to convert user input from string to integer, float, and boolean types.
input_str=input("Enter a string:")
int_value=int(input_str)
float_value=float(input_str)
bool_value=bool(input_str)
print("string:, input_str")
print("integer:,int_value")
print("float:,float_value")
print("boolean:, bool_value")

#Write code to demonstrate type casting with list elements.
str_list=['1','2','3','4','5']
int_list=[int(x) for x in str_list]
float_list=[float(x) for x in str_list]
print("string list:, str_list")
print("integer list:, int_list")
print("float list:, float_list")

#Write a program that checks if a number is positive, negative, or zero.
num=float(input("Enter a number:"))
if num>0:
  print("The number is positive:")
elif num<0:
    print("The number is negative:")
else:
    print("The number is zero:")

 #Write a for loop to print numbers from 1 to 10.
for i in range (1,11):
 print(i)
i=1
while i<=10:
  print(i)
  i += 1

# Write a Python program to find the sum of all even numbers between 1 and 50.
even_sum =0
for num in range(1,51):
 if i % 2 == 0:
  even_sum +=i
  print("Sum of even number 1 and 50 is:", even_sum)

# Write a program to reverse a string using a while loop.
input_str=input("Enter a string:")
reversed_str=""
index=len(input_str)-1
while index>=0:
  reversed_str += input_str[index]
  index -=1
  print("Reversed string:, reversed_str")

# Write a Python program to calculate the factorial of a number provided by the user using a while loop
num=int(input("Enter a number:"))
factorial=1
while num>0:
  factorial *=num
  num -=1
  print("Factorial:", factorial)
# Out:
# Hello,World
# Enter your name:Muskan Dixit
# Enter you age25
# Name, name
# Age, age
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 1) What is Python, and why is it popular?
#  - Python is a high level general purpose programming language known for its simplicity.readibility and versatility created by Guido van Rossum and released in 1991.It is used in a versatile manner.
#
# 2) What is an interpreter in Python?
# - It is a program that reads and executes python code line by line.
#   Commonly used interpreters are CPython,PyPy.
#
# 3)What are pre-defined keywords in Python?
# - Predefined keywords in python are the reserved words that have special meaning in the language.These keywords are used to define syntax and structures,we cannot use them as variable names.
#
# 4)Can keywords be used as variable names?
#     - No, keywords can't be used as variable names.
#
# 5)What is mutability in Python?
# - Mutability refers to whether the value of an object can be changed after it is created.
#
#  6) Why are lists mutable, but tuples are immutable?
#  - List are designed for flexibility.We often need to change,add or remove items Whereas tuples are designed for fixed,stable data like coordinates,setting, or values that shouldn't change.
# - List need more overhead to support operations like append(),remove(),etc whereas tuples use less memory and are faster than list.
#
#  7)What is the difference between “==” and “is” operators in Python?
#   - '==' checks if the value of two variables are equal and compares the content whereas 'is' operatorchecks if both variables point to the same object in memory and compares identity,not value.
#
# 8)What are logical operators in Python?
#   - Logic operators are used to combine conditional statements and return True or False based on logical relationship.Examples- and, or, not.
#
# 9) What is type casting in Python?
#   - Typecasting means converting one datat type into another, such as from a string to an integer or a float to a string.
#
# 10)What is the difference between implicit and explicit type casting?
#   - Implicit typecasting is done automatically, error chances are low.It helps in combining like (int+float) whereas explicit typecasting is done manually which might cause error.It is used to change input/output type.
#
#  11) What is the purpose of conditional statements in Python?
#   - Conditional Statements are used to make decisions in a program.They let our code perform different actions depending on whether a condition is True or False.
#
#   12) How does the elif statement work?
#   - The elif statement in python means else if.It is used to check multiple conditions one after another-if the first condition is false, Python checks the next one.
#
#   13)What is the difference between for and while loops?
#   - For Loop- It works for making sequence,it is used when number of iterations is known.
#   While Loop- It works as long as the condition is True,also used when number of iterations is unknown.
#
#   14)Describe a scenario where a while loop is more suitable than a for loop.
#   - If we are building a login system that asks the user to enter the correct password, username then it is highly preferred to use while loop.
